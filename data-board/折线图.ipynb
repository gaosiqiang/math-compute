# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([1, 2, 3, 4, 5, 6])
y1 = np.array([3, 7, 5, 9, 1, 4])
x2 = np.array([1, 2, 3, 4, 5, 6])
y2 = np.array([6, 2, 13, 10, 3, 4])

plt.plot(x1, y1, x2, y2)
plt.show()
